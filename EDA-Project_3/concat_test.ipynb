# %%
import pandas as pd 

df = pd.read_csv('data\submission.csv')

df['reviewer_score'].nunique()
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\nitys\AppData\Local\Temp\ipykernel_23764\438071947.py:3: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv('data\submission.csv')
# 10

# %%
df_hot_test = pd.read_csv('data\hotels_test.csv')
df_hot_test
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\h'
# <>:1: SyntaxWarning: invalid escape sequence '\h'
# C:\Users\nitys\AppData\Local\Temp\ipykernel_23764\1008974004.py:1: SyntaxWarning: invalid escape sequence '\h'
#   df_hot_test = pd.read_csv('data\hotels_test.csv')
#                                             hotel_address  \
# 0                      Via Senigallia 6 20161 Milan Italy
# 1       Arlandaweg 10 Westpoort 1043 EW Amsterdam Neth...
# 2             Mallorca 251 Eixample 08008 Barcelona Spain
# 3       Piazza Della Repubblica 17 Central Station 201...
# 4       Singel 303 309 Amsterdam City Center 1012 WJ A...
# ...                                                   ...
# 128930  Viale Monza 132 Distretto Viale Monza 20127 Mi...
# 128931  Duc De Medinaceli 8 Ciutat Vella 08002 Barcelo...
# 128932  Wiedner Hauptstra e 44 04 Wieden 1040 Vienna A...
# 128933  Corso Concordia 1 Milan City Center 20129 Mila...
# 128934       202 rue de Rivoli 1st arr 75001 Paris France
#
# ...

# %%
import pandas as pd

hotel_to_concat = pd.read_csv('data\hotels.csv')
hotel_to_concat.head()

url = 'https://drive.google.com/file/d/1Je7KPhWfrZguhSORm1EccY2MWFRCNpDk/view?usp=drive_link'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]

vader_scores = pd.read_csv(url)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\h'
# <>:3: SyntaxWarning: invalid escape sequence '\h'
# C:\Users\nitys\AppData\Local\Temp\ipykernel_45512\1877057163.py:3: SyntaxWarning: invalid escape sequence '\h'
#   hotel_to_concat = pd.read_csv('data\hotels.csv')

# %%
display(vader_scores.head())

hotel_to_concat = pd.concat([hotel_to_concat, vader_scores], axis=1)

hotel_to_concat.head()
# vader_scores
# Out:
#    vader_score  vader_score_pos  vader_score_neg
# 0       0.8126            0.655            0.000
# 1      -0.4767            0.000            0.756
# 2      -0.7096            0.000            0.423
# 3       0.9477            0.721            0.000
# 4       0.7893            0.382            0.667
#                                        hotel_address  \
# 0  Stratton Street Mayfair Westminster Borough Lo...
# 1  130 134 Southampton Row Camden London WC1B 5AF...
# 2   151 bis Rue de Rennes 6th arr 75006 Paris France
# 3  216 Avenue Jean Jaures 19th arr 75019 Paris Fr...
# 4          Molenwerf 1 1014 AG Amsterdam Netherlands
#
#    additional_number_of_scoring review_date  average_score  \
# 0                           581   2/19/2016            8.4
# 1                           299   1/12/2017            8.3
# 2                            32  10/18/2016            8.9
# 3                            34   9/22/2015            7.5
# ...

# %%
import pandas as pd


vader_vader = pd.read_csv('data/vader_scores.csv')

vader_vader.shape
# Out:
# (386496, 3)

# %%
date = '16.05.2019 15:59'

# date = date.split(' ')
# ['16.04.2019', '15:15']

# date = date[0].split('.')
# ['16', '04', '2019']

# if int(date[2]) < 2019:
#     category = 3
#     print('1')
# if int(date[1]) in list(range(5)):
#     category = 2
#     print('2')
# if int(date[1]) == 5:
#     category = 1
#     print(3)    
    
    
year = int(date[6:10])
month = int(date[3:5])

date
# Out:
# 5

# %%
print(list(range(5)))
# Out:
# [0, 1, 2, 3, 4]

# %%
Ni = 'NiagaraFalls'
Lo = 'Louvre'

places = [Ni, Lo]

location = {
    Ni : 'USA',
    Lo : 'France'
    }

print('Ссылка на значение переменной Ni: ', id(Ni))
print('Ссылка на значение переменной Lo: ', id(Lo), '\n')
print(" ID 'NiagaraFalls': ", id('NiagaraFalls'))        
print(" ID 'Louvre': ", id('Louvre'),'\n')        

for place in places:
    
    print(f'Ссылка на значение переменной {place}: ', id(place))
    
    country = location[place]
    
    if country != 'Russia':
        
        place = 'Unavailable'
        print(f'Ссылка на значение переменной place (после перезаписи) = Unavailable: ', id(place), '\n')

print('Ссылка на значение переменной Ni: ', id(Ni))
print('Ссылка на значение переменной Lo: ', id(Lo), '\n')
# Out:
# Ссылка на значение переменной Ni:  1718672748784
# Ссылка на значение переменной Lo:  1718666689536
#
#  ID 'NiagaraFalls':  1718672748784
#  ID 'Louvre':  1718666689536
#
# Ссылка на значение переменной NiagaraFalls:  1718672748784
# Ссылка на значение переменной place (после перезаписи) = Unavailable:  1718666924400
#
# Ссылка на значение переменной Louvre:  1718666689536
# Ссылка на значение переменной place (после перезаписи) = Unavailable:  1718666924400
#
# Ссылка на значение переменной Ni:  1718672748784
# Ссылка на значение переменной Lo:  1718666689536

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk import tokenize
nltk.download('vader_lexicon')

def vader_analitics_negative(review):
    sid = SentimentIntensityAnalyzer()
    ss = sid.polarity_scores(review)
    for k in sorted(ss):
        print('{0}: {1}, '.format(k, ss[k]), end='')
    
review = "Max is a great guy, but sometimes looks like he doesn't care to you"
# compound: 0.3309, neg: 0.179, neu: 0.52, pos: 0.301,

review = "Max is a great guy, despite that sometimes looks like he doesn't care to you"
# compound: 0.6088, neg: 0.13, neu: 0.544, pos: 0.326, 

review = "Max is a great guy, he has a lot of good human qualities"

# review = "Max is a great guy, and it doesn't matter that sometimes looks like he doesn't care to you"

# review = "Despite that sometimes looks like Max doesn't care to you, he is a great guy"
# compound: 0.6088, neg: 0.13, neu: 0.544, pos: 0.326, [nltk_data] Downloading package vader_lexicon to

# review = 'Good day'

vader_analitics_negative(review)
# Out:
# compound: 0.7906, neg: 0.0, neu: 0.562, pos: 0.438,
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\nitys\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
from textblob import TextBlob

text = "today is a good day"

blob = TextBlob(text)

blob.tags  # [('The', 'DT'), ('titular', 'JJ'),
#  ('threat', 'NN'), ('of', 'IN'), ...]

blob.noun_phrases  # WordList(['titular threat', 'blob',
#            'ultimate movie monster',
#            'amoeba-like mass', ...])

for sentence in blob.sentences:
    print(sentence.sentiment.polarity)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\textblob\decorators.py:35, in requires_nltk_corpus.<locals>.decorated(*args, **kwargs)
#      34 try:
# ---> 35     return func(*args, **kwargs)
#      36 except LookupError as error:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\textblob\tokenizers.py:59, in SentenceTokenizer.tokenize(self, text)
#      58 """Return a list of sentences."""
# ---> 59 return nltk.tokenize.sent_tokenize(text)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\nltk\tokenize\__init__.py:119, in sent_tokenize(text, language)
#     110 """
#     111 Return a sentence-tokenized copy of *text*,
#     112 using NLTK's recommended sentence tokenizer
#    (...)
#     117 :param language: the model name in the Punkt corpus
#     118 """
# ...

# %%
from textblob import TextBlob

text = """
The titular threat of The Blob has always struck me as the ultimate movie
monster: an insatiably hungry, amoeba-like mass able to penetrate
virtually any safeguard, capable of--as a doomed doctor chillingly
describes it--"assimilating flesh on contact.
Snide comparisons to gelatin be damned, it's a concept with the most
devastating of potential consequences, not unlike the grey goo scenario
proposed by technological theorists fearful of
artificial intelligence run rampant.
"""

blob = TextBlob(text)
blob.tags[('The', 'DT'), ('titular', 'JJ'), ('threat', 'NN'), ('of', 'IN')]

blob.noun_phrases(['titular threat', 'blob',
           'ultimate movie monster',
           'amoeba-like mass', ...])

for sentence in blob.sentences:
    print(sentence.sentiment.polarity)
# 0.060
# -0.341
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\textblob\decorators.py:35, in requires_nltk_corpus.<locals>.decorated(*args, **kwargs)
#      34 try:
# ---> 35     return func(*args, **kwargs)
#      36 except LookupError as error:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\textblob\tokenizers.py:59, in SentenceTokenizer.tokenize(self, text)
#      58 """Return a list of sentences."""
# ---> 59 return nltk.tokenize.sent_tokenize(text)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\nltk\tokenize\__init__.py:119, in sent_tokenize(text, language)
#     110 """
#     111 Return a sentence-tokenized copy of *text*,
#     112 using NLTK's recommended sentence tokenizer
#    (...)
#     117 :param language: the model name in the Punkt corpus
#     118 """
# ...

# %%
import pandas as pd
hotels_orig = pd.read_csv('data/hotels.csv')

# %%
hotels_orig = hotels_orig.drop_duplicates()

# %%
hotels_orig.iloc[333937]['positive_review']
# Out:
# ' 1h30 in the night when we try to check in There is a nightclub at ne side of the hotel and there was a party at the other side Party people were with their loud music under the bridge dancing and having a party outside the club Reception did not all police Visitors of hotel were at the reception complaining Airco in the hotel did not work People complaining of headache and could not open window because of the loud music Temperature was 30C in the day Not possible to stay Worst hotel we ever experienced and lots of others wanted to leave in the morning We left the hotel and had to look for other hotel Finally could go to sleep at 4 in the night Excellent stay in Pullman Hotel with excellent service '

# %%
hotels_orig.iloc[191387]
# Out:
# hotel_address                                 7 11 Queensberry Place Kensington and Chelsea ...
# additional_number_of_scoring                                                                234
# review_date                                                                            8/6/2016
# average_score                                                                               6.9
# hotel_name                                                                   Gainsborough Hotel
# reviewer_nationality                                                                 Australia
# negative_review                                                                     Everything
# review_total_negative_word_counts                                                             3
# total_number_of_reviews                                                                    1884
# positive_review                                This was to be our last nights in London We c...
# ...

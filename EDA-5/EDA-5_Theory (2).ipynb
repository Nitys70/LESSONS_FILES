# %%
import pandas as pd

df = pd.read_csv('data/KaggleV2-May-2016.csv')

df.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# ...

# %% [markdown]
# # Logging

# %%
# импорт библиотеки логирования 
# импорт модуля перезагрузки (требуется для 
# того, чтобы сбросить дефолтные настройки 
# модуля логирования (по умолчанию логирование 
# происходит начиная с уровня warning) /
import logging
from importlib import reload

reload(logging)

logging.basicConfig(
    format="%(levelname)s: %(asctime)s: %(message)s",
    level=logging.DEBUG
)

logging.info('Check')
# Out:
# INFO: 2024-10-13 14:13:00,782: Check

# %% [markdown]
# ___
# # COMET

# %%
from comet_ml import Experiment

experiment = Experiment(
    api_key='XvO6XLBaKx0lDLErozXowyiib',
    project_name='medical-appointment',
    workspace='nitys'
)
# Out:
# DEBUG: 2024-10-13 17:10:52,672: No INI file found: []
# DEBUG: 2024-10-13 17:10:52,672: No INI file found: ['./.comet.config']
# DEBUG: 2024-10-13 17:10:52,672: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2024-10-13 17:10:52,675: No INI file found: ['~/.comet.config']
# DEBUG: 2024-10-13 17:10:52,675: Looking up key: disable, namespace: ['comet', 'auto_log']
# DEBUG: 2024-10-13 17:10:52,675: Searching <ConfigOSEnv> for COMET_AUTO_LOG_DISABLE
# DEBUG: 2024-10-13 17:10:52,675: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_DISABLE
# DEBUG: 2024-10-13 17:10:52,675: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_DISABLE
# DEBUG: 2024-10-13 17:10:52,679: Found nothing--returning NO_VALUE
# DEBUG: 2024-10-13 17:10:52,679: Looking up key: url_override, namespace: ['comet']
# DEBUG: 2024-10-13 17:10:52,680: Searching <ConfigOSEnv> for COMET_URL_OVERRIDE
# DEBUG: 2024-10-13 17:10:52,680: Searching <ConfigEnvFileEnv: None> for COMET_URL_OVERRIDE
# ...

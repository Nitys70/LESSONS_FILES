# %% [markdown]
# ****
# # CSV, EXCEL
#
# ****

# %%
import pandas as pd

countries_data = pd.read_csv('data/countries.csv', sep=';')
countries_data.to_csv('data/counties.txt', sep=' ', index=False)

txt_df = pd.read_table('data/counties.txt', sep=' ', index_col=('country'))
txt_df
# Out:
#            population    square
# country
# Англия          56.29    133396
# Канада          38.05   9984670
# США            322.28   9826630
# Россия         146.24  17125191
# Украина         45.50    603628
# Беларусь         9.50    207600
# Казахстан       17.04   2724902

# %%
data = pd.read_csv(
    'data/ErrorEnCoding.csv', 
    header=None, encoding_errors='replace'
    )

display(data)

from chardet.universaldetector import UniversalDetector

detector = UniversalDetector()

with open('data/ErrorEnCoding.csv', 'rb') as fh:
    for line in fh: 
        detector.feed(line)
        if detector.done:
            break
print(detector.close())


data = pd.read_csv(
    'data/ErrorEnCoding.csv', 
    header=None, encoding='KOI8-R'
    )

display(data)
# Out:
#             0                           1             2
# 0   User_943         Accumanst@gmail.com         ������
# 1   User_908           Advismowr@mail.ru         ������
# 2   User_962             Anachso@ukr.net      ���������
# 3   User_973            Antecia@inbox.ru          �����
# 4   User_902          Balliaryva@ukr.net
# ..        ...                         ...           ...
# 95  User_959    UpdatesCurious@yahoo.com         ������
# 96  User_901          V2artierso@mail.ru    �����������
# 97  User_970            Vashoterlo@bk.ru        �������
# 98  User_965         Visuareda@yahoo.com        �������
# 99  User_921                Aavast@ya.ru         ������
#
# [100 rows x 3 columns]
# {'encoding': 'KOI8-R', 'confidence': 0.8773902118791048, 'language': 'Russian'}
#             0                           1             2
# 0   User_943         Accumanst@gmail.com         Ижевск
# 1   User_908           Advismowr@mail.ru         Ижевск
# ...

# %%
data = pd.read_table('https://raw.githubusercontent.com/esabunor/MLWorkspace/master/melb_data.csv', sep=',')
display(data)
# Out:
#        Unnamed: 0        Suburb           Address  Rooms Type      Price  \
# 0               1    Abbotsford      85 Turner St      2    h  1480000.0
# 1               2    Abbotsford   25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford      5 Charles St      3    h  1465000.0
# 3               5    Abbotsford  40 Federation La      3    h   850000.0
# 4               6    Abbotsford       55a Park St      4    h  1600000.0
# ...           ...           ...               ...    ...  ...        ...
# 18391       23540  Williamstown   8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown      96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville        6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville     33 Freeman St      4    h  1050000.0
#
#       Method     SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# ...

# %%
data = pd.read_csv('Data\students_performance.zip')

display(data)

compression_opts = dict(method='zip', archive_name='out.csv')

data.to_csv('data/data.zip', index=False, compression=compression_opts)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\nitys\AppData\Local\Temp\ipykernel_7176\746397923.py:1: SyntaxWarning: invalid escape sequence '\s'
#   data = pd.read_csv('Data\students_performance.zip')
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# ...

# %%
grades = pd.read_excel('data/grades.xlsx')

display(grades.head())
# Out:
#    Student ID Student name  Grade
# 0           1          Аня      8
# 1           2         Катя      9
# 2           3         Маша      7
# 3           4         Миша      4
# 4           5         Женя      8

# %%
data = pd.read_excel('https://github.com/asaydn/test/raw/master/january.xlsx', skiprows=3)
display(data)
# Out:
#       Location  Oranges  Apples  Bananas  Blueberries  Total
# 0      Toronto     7651    4422     8580         3679  24332
# 1  Los Angeles      273    2998     9890         7293  20454
# 2      Atlanta     3758    6752     4599         4149  19258
# 3     New York     4019    8796     8486         9188  30489

# %%
grades = pd.read_excel('data/grades.xlsx', sheet_name='ML')
display(grades[grades['Student name'] == 'Катя'])

grades_math = pd.read_excel('data/grades.xlsx', sheet_name='Maths')
display(grades_math[grades_math['Student name'] == 'Миша'])
# Out:
#    Student ID Student name  Grade
# 1           2         Катя      5
#    Student ID Student name  Grade
# 3           4         Миша      4

# %%
import pandas as pd

ratings_df = pd.read_excel('data/ratings_movies.xlsx', sheet_name='ratings')
movies_df = pd.read_excel('data/ratings_movies.xlsx', sheet_name='movies')



display(ratings_df.head())
display(movies_df.head())

movies_rating_df = ratings_df.join(
    movies_df.set_index('movieId'),
    on='movieId',
    how = 'left'
)

movies_rating_df

movies_rating_df.to_excel('data/movies_rating_df.xlsx')
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# ****
# # JSON
#
# ****

# %%
import json 

from pprint import pprint

with open('data/recipes.json') as f:
    recipes = json.load(f)
    
pprint(recipes[:1]) 

len(recipes[0]['ingredients'])

for elem in recipes:
    if elem['id'] == 13121:
        print(elem['cuisine'])
        
cuisine_set = set()

for elem in recipes:
    cuisine_set.add(elem['cuisine'])
    
print(len(cuisine_set))


#
#### Какая самая большая по рецептам кухня
#

# Создадим словарь ключ - кухня - значение 0
cuisine_dict = dict()
for elem in cuisine_set:
    cuisine_dict[elem] = 0

# Наполним словарь значениями - упоминания кухонь

for elem in recipes:
    cuisine_dict[elem['cuisine']] +=1
    

cuisne_list = list(cuisine_dict.items())

cuisne_list = sorted(cuisne_list, key = lambda x: x[1])
cuisne_list[-1][0]
# Out:
# [{'cuisine': 'greek',
#   'id': 10259,
#   'ingredients': ['romaine lettuce',
#                   'black olives',
#                   'grape tomatoes',
#                   'garlic',
#                   'pepper',
#                   'purple onion',
#                   'seasoning',
#                   'garbanzo beans',
#                   'feta cheese crumbles']}]
# thai
# 20
# 'italian'

# %% [markdown]
# ****
# # Из JSON в pandas
#
# ****

# %%
import json 
from pprint import pprint
import pandas as pd


with open('data/recipes.json') as f:
    recipes = json.load(f)
    
df = pd.DataFrame(recipes)

display(df.head())

# df_2 = pd.read_json('data/recipes.json')

# display(df_2.head())

df.info()

all_ingredients = set()

for elem in recipes:
    for elem in elem['ingredients']:
        all_ingredients.add(elem)

all_ingredients = list(all_ingredients)
len(all_ingredients)

for elem in all_ingredients:
    df[elem] = 0
    
df.head()

def contains(ingredient_list):
    
    if ingredient_name in ingredient_list:
        return 1
    else:
        return 0
    
for ingredient_name in all_ingredients:
    df[ingredient_name] = df['ingredients'].apply(contains)
    
df['ingredients'] = df['ingredients'].apply(len)

ids = list(df['id'])
ids

df.to_csv('data/recipes.csv', index=False)
# Out:
#       id      cuisine                                        ingredients
# 0  10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1  25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2  20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3  22213       indian                [water, vegetable oil, wheat, salt]
# 4  13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           500 non-null    int64
#  1   cuisine      500 non-null    object
#  2   ingredients  500 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 11.8+ KB
# ...

# %% [markdown]
# ****
# # ИЗ PANDAS В JSON
#
# ****

# %%
import json 
from pprint import pprint
import pandas as pd
from collections import OrderedDict

df = pd.read_csv('data/recipes.csv')

ciusine_to_insert = df['cuisine']

df= df.drop(['cuisine'], axis = 1)

df.insert(0, 'cuisine', ciusine_to_insert)

df.head()

ids = list(df['id'])


ingredients = df.columns.to_list()[3:]
ingredients


# def make_list():
    
    

display(df[df['id'] == 25693])

for current_id in ids[:3]:
    print(current_id) 
    
test_df = df[df['id'] == 25693]


# Эта функция возвращает словарь - элемент json сразу и целиком
def make_list(df_row):

    dr_row_dict = df_row.to_dict()

    returnable_dict = dict()
 
    for elem in dr_row_dict.items():
        if elem[1] != {1:0}:
            returnable_dict.update({elem[0]: elem[1][1]})
            

    exclude_list = ['cuisine', 'id', 'ingredients' ]
    ingredients_list = []
    for elem in returnable_dict:
        if elem not in exclude_list:
            ingredients_list.append(elem)
    
    returnable_dict['ingredients'] = ingredients_list    

    return returnable_dict

df.apply(make_list)
# Out:
#        cuisine     id  ingredients  balsamic vinegar  frozen blueberries  \
# 1  southern_us  25693           11                 0                   0
#
#    sliced mushrooms  greek yogurt  giardiniera  fresh raspberries  olive oil  \
# 1                 0             0            0                  0          0
#
#    ...  ground nutmeg  cajun seasoning  canned low sodium chicken broth  \
# 1  ...              0                0                                0
#
#    greens  plum sauce  fresh fava bean  spring onions  pizza crust  \
# 1       0           0                0              0            0
#
#    monterey jack  kalonji
# 1              0        0
#
# [1 rows x 1321 columns]
# 10259
# 25693
# 20130
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 57
#      53     returnable_dict['ingredients'] = ingredients_list
# ...

# %%
import json 
from pprint import pprint
import pandas as pd
from collections import OrderedDict

df = pd.read_csv('data/recipes.csv')

row = df.iloc[1]
row_copy = row.copy()

n=0

ids = list(df['id'])

ciusine_to_insert = df['cuisine']

df= df.drop(['cuisine'], axis = 1)

df.insert(0, 'cuisine', ciusine_to_insert)

def make_list(row):

    ingredients = list()

    for count in range(3, 1321):
       
        if row[count] != 0:
            ingredients.append(row.index[count])
    
    return ingredients
        

new_recipes = [] 
# Организуем цикл с параметром current_id
for current_id in ids: 
    # Получаем значение соответствующей кухни, применив фильтр по текущему значению параметра цикла к DataFrame;
    cuisine = df[df['id'] == current_id]['cuisine'].iloc[0] 
    # Получаем перечень ингредиентов, входящих в состав текущего блюда
    current_ingredients = make_list(df.loc['id' == current_id]) 
    # Создаём текущий словарь
    current_recipe = {'cuisine': cuisine, 'id': int(current_id), 'ingredients': current_ingredients} 
    # Добавляем созданный словарь к списку
    new_recipes.append(current_recipe)
    
# cuisine = df[df['id'] == 10259]['cuisine'].iloc[0] 
# cuisine
# df[df['id'] == 10259]

# ids

# make_list(df[df['id'] == 10259])

row = df[df['id'] == 10259]

# ingredients = list()

# for count in range(3, 1321):
    
#     if row[count] != 0:
#         ingredients.append(row.index[count])

# print(ingredients)
display(row)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 39
#      37 cuisine = df[df['id'] == current_id]['cuisine'].iloc[0]
#      38 # Получаем перечень ингредиентов, входящих в состав текущего блюда
# ---> 39 current_ingredients = make_list(df.loc['id' == current_id])
#      40 # Создаём текущий словарь
#      41 current_recipe = {'cuisine': cuisine, 'id': int(current_id), 'ingredients': current_ingredients}
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...

# %%
import json 
import pandas as pd


df = pd.read_csv('data/recipes.csv')

row = df.iloc[1]
row_2 = df[df['id'] == 25693]


# # def make_list(row):

# #     ingredients = list()

# #     for count in range(3, 1321):
       
# #         if row[count] != 0:
# #             ingredients.append(row.index[count])
    
# #     return ingredients


# # Тип данных в проверке задачи 7.3
# print(type(row))
# #<class 'pandas.core.series.Series'>

# # Тип данных по коду (в части сериализации)
# print(type(row_2))
# #<class 'pandas.core.frame.DataFrame'>

# try:
#     make_list(row_2)
# except:
#     print('Операция не удалась, типа данных - ', type(row_2))
# # Операция не удалась, типа данных -  <class 'pandas.core.frame.DataFrame'>

# ingredients = make_list(row)
# print(ingredients)
# #['green tomatoes', 'ground black pepper', 'yellow corn meal', 
# # 'eggs', 'ground pepper', 'plain flour', 'tomatoes', 
# # 'thyme', 'milk', 'salt', 'vegetable oil']

row_2

ingredients = list(df.columns[3:])

def make_list(row):
    ingredient_list = []
    for ingredient in ingredients:
        if row[ingredient].item() == 1:
            ingredient_list.append(ingredient)
    return ingredient_list

# make_list(row)

# ingredients

row[1]
row['milk'].item()

row_2.iloc[0][2]

row_2_dict = row_2.to_dict()

print(row_2_dict)
# Out:
# {'id': {1: 25693}, 'cuisine': {1: 'southern_us'}, 'ingredients': {1: 11}, 'balsamic vinegar': {1: 0}, 'frozen blueberries': {1: 0}, 'sliced mushrooms': {1: 0}, 'greek yogurt': {1: 0}, 'giardiniera': {1: 0}, 'fresh raspberries': {1: 0}, 'olive oil': {1: 0}, 'pecorino cheese': {1: 0}, 'broccoli': {1: 0}, 'green tomatoes': {1: 1}, 'lemon': {1: 0}, 'couscous': {1: 0}, 'unsalted butter': {1: 0}, 'pound cake': {1: 0}, 'phyllo': {1: 0}, 'chillies': {1: 0}, 'wheat bran': {1: 0}, 'parmigiano reggiano cheese': {1: 0}, 'oil': {1: 0}, 'vegetable oil cooking spray': {1: 0}, 'asparagus tips': {1: 0}, 'rice flour': {1: 0}, 'lump crab meat': {1: 0}, 'spaghetti': {1: 0}, 'reduced fat swiss cheese': {1: 0}, 'SargentoВ® Traditional Cut Shredded Mozzarella Cheese': {1: 0}, 'thai chile': {1: 0}, 'egg whites': {1: 0}, 'fresh bay leaves': {1: 0}, 'cream': {1: 0}, 'roma tomatoes': {1: 0}, 'stock': {1: 0}, 'green onions': {1: 0}, 'iceberg lettuce': {1: 0}, 'pork': {1: 0}, 'chocolate bars': {1: 0}, 'parsnips'
# ...

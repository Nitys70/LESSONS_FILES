# %%
import pandas as pd

df = pd.read_csv('data/dst-3.0_16_1_hh_database.csv', sep=';')

missed_data_2 = list( df[df.isna().any(axis=1)].index )

# display(df.head())

# def education_class(elem):
#     elem=elem.lower()
#     if 'неоконченное высшее' in elem:
#         elem = 'неоконченное высшее'
#     elif 'высшее' in elem:
#         elem = 'высшее'
#     if 'среднее специальное' in elem:
#         elem = 'среднее специальное'
#     elif 'среднее' in elem:
#         elem = 'среднее'    
#     return elem

# df['Образование'] = df['Образование и ВУЗ'].apply(education_class)

# # display(df[df['Образование'] == 'среднее'].head(5))
# df['Образование']=df['Образование'].astype('category')
# # df.info()
# # df.info()
# # df['Образование'].cat.categories

# df['Пол'] = df['Пол, возраст'].apply(
#     lambda x: 'М' if 'Мужчина' in x else 'Ж'
#     )

# df['Пол'].value_counts()

# df['Возраст'] = df['Пол, возраст'].apply(lambda x: int(x.split(' ')[3]) )
# df.head()

# def exprns(elem):
#     try:
#         counter = 0
#         elem = elem.split(' ')
#         if 'го' or 'ле' in elem[3]:
#             counter += int(elem[2])*12
        
#         if 'мес' in elem[3]:
#             counter += int(elem[2])
        
#         if 'мес' in elem[5]:
#             counter += int(elem[4])
        
#         return counter
    
#     except:
#         return None
    
# df['Опыт работы (месяц)'] = df['Опыт работы'].apply(exprns)

# df[df['Опыт работы (месяц)'] == 'NaN'].head()          



# def city_filling(elem):
#     million_cities = ['Новосибирск', 'Екатеринбург', 'Нижний Новгород', 
#                   'Казань', 'Челябинск', 'Омск', 'Самара', 
#                   'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 
#                   'Воронеж', 'Волгоград' 
#                   ]
    
#     elem = elem.split(',')
#     city = ''

#     if 'Москва' in elem[0] or 'Санкт-Петер' in elem[0]:
#         city = elem[0]
#     elif elem[0] in million_cities:
#         city = 'город-миллионник'
#     else:
#         city = 'другие'
        
#     return city

# df['Город'] = df['Город, переезд, командировки'].apply(city_filling)

# df.head()


# # Функция для вычленения элемента тематики перезда и его обработка

# def relocate(elem):
#     elem = elem.split(',')
#     item_relocate = 'переезд'

#     for item_relocate in elem:
#         if item_relocate in elem:
#             if 'не' in elem:
#                 return False
#             else:
#                 return True
            

# # Функция для вычленения элемента тематики командировки и его обработка,

# def bis_trip(elem):
#     elem = elem.split(',')
#     item_bis_trip = 'коман'

#     if item_bis_trip in elem[-1]:
#         if 'не' in elem[-1]:
#             return False
#         else:
#             return True 
#     else:
#         return False 


# df['Готовность к переезду'] = df['Город, переезд, командировки'
#                                  ].apply(relocate)
# df['Готовность к командировкам'] = df['Город, переезд, командировки'
#                                       ].apply(bis_trip)


# df[df.isna().any(axis=1)]

print(missed_data_2)

print(df.info())

display(df[df['Опыт работы'].isna() == True])
display(df.loc[64, 118])
# Out:
# [64, 118, 330, 413, 1170, 1207, 1258, 2104, 2310, 2489, 2796, 3426, 3431, 3474, 3733, 3872, 3987, 4305, 4421, 4483, 4637, 4648, 4910, 5271, 5305, 5511, 5600, 5725, 5820, 5831, 6189, 6998, 7035, 7310, 7370, 7687, 7723, 8166, 8694, 8870, 8992, 9016, 9196, 9254, 9267, 9320, 9470, 9605, 9652, 9727, 10125, 10166, 10313, 10563, 10844, 11112, 11314, 11411, 12478, 12709, 13055, 13597, 14414, 14475, 14744, 14890, 14948, 15245, 15254, 15502, 15538, 15802, 16107, 16302, 17411, 17918, 18070, 18156, 18196, 18252, 18310, 18427, 18508, 18597, 18987, 19163, 19246, 19546, 19719, 20874, 21084, 21267, 21899, 21937, 22527, 22839, 22938, 23074, 23302, 23586, 23842, 23844, 23928, 23971, 25000, 25188, 25292, 25646, 25880, 26058, 26078, 26217, 26474, 26497, 26510, 26886, 27203, 27571, 28125, 28528, 28762, 29568, 29884, 29951, 29962, 30002, 31207, 31800, 31895, 32299, 33195, 33423, 33778, 34115, 34664, 34742, 34746, 35010, 35219, 36170, 36177, 36252, 36301, 36308, 36956, 37063, 38048, 38240, 38452, 38823, 38
# ...

# %%
a = ['f', 'd']

b = 'f'

if b in a:
    print('Yes')
else:
    print('No')
# Out:
# Yes

# %%
import pandas as pd

df = pd.read_csv('data/dst-3.0_16_1_hh_database.csv', sep=';')

new_df = df.copy()

def city_filling(elem):
    million_cities = ['Новосибирск', 'Екатеринбург', 
                      'НижнийНовгород', 'Казань', 'Челябинск', 
                      'Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 
                      'Красноярск', 'Пермь', 'Воронеж', 'Волгоград', 'Тверь'
                      ]
    
    elem = elem.split(',')
    # city = ''

    if 'Москва' in elem[0] or 'Санкт-Петер' in elem[0]:
        city = elem[0]
    elif elem[0].replace(' ','') in million_cities:
        city = 'город-миллионник'
    else:
        city = 'другие'
    
    print(elem[0])
        
    return city

new_df['Город'] = new_df['Город, переезд, командировки'
                       ].apply(city_filling)

display(new_df[100:120])
# Out:
# Советск (Калининградская область)
# Королев
# Тверь
# Саратов
# Москва
# Старый Оскол
# Москва
# Москва
# Москва
# Москва
# Москва
# Москва
# Старый Оскол
# Москва
# Калининград
# Ярославль
# Москва
# Великие Луки
# Москва
# Новосибирск
# Москва
# Обнинск
# Сочи
# Пенза
# Казань
# Зеленодольск (Республика Татарстан)
# Москва
# Москва
# Владимир
# Санкт-Петербург
# Минск
# Москва
# Санкт-Петербург
# Нижний Тагил
# Санкт-Петербург
# Пермь
# Орск
# Санкт-Петербург
# Ярославль
# Воронеж
# Москва
# Москва
# Калуга
# Москва
# Москва
# Москва
# Томск
# Москва
# Красноярск
# Тюмень
# Стерлитамак
# Владимир
# Москва
# Кемерово
# Санкт-Петербург
# Москва
# Санкт-Петербург
# Губкин
# Краснодар
# Красноярск
# Барнаул
# Тюмень
# Ростов-на-Дону
# Вологда
# Санкт-Петербург
# Великий Новгород
# Москва
# Томск
# Новокузнецк
# Энем
# Москва
# Смоленск
# Москва
# Подольск (Московская область)
# Красноярск
# Симферополь
# Хабаровск
# Санкт-Петербург
# Краснодар
# Москва
# Москва
# Алматы
# Талица
# ...

# %%
a = 'Москва , не готова к переезду , готова к кома..'

a = a.split(',')
a
item_relocate = 'переезд'

for elem in a:
    if item_relocate in elem:
        if 'не' in elem:
            print('False')
        else:
            print('True')

item_bis_trip = 'коман'

if item_bis_trip in a[-1]:
    if 'не' not in a[-1]:
        print('True')
    else:
        print('False') 
else:
    print('Flase nono') 

# for elem in a:
#     if item_bis_trip not in elem:
#         print('Flase nono')
        
#     else:
#         if item_bis_trip in elem:
#             if 'не' not in elem:
#                 print('True')
#             else:
#                 print('False')



# if item in a:
#     print(a)
# print(b)
# Out:
# False
# Flase nono

# %%
a = 'Москва , не готова к переезду , готова к коман..'

a = a.split(',')

million_cities = ['Новосибирск', 'Екатеринбург', 'Нижний Новгород', 
                'Казань', 'Челябинск', 'Омск', 'Самара', 
                'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 
                'Воронеж', 'Волгоград' 
                ]

if 'Москва' in a[0] or 'Санкт-Петер' in a[0]:
        print('Yep', a[0])
elif a[0] in million_cities:
        print('город-миллионник')
else:
        print('другие')

print(a[0])

type(a)
# Out:
# Yep Москва
# Москва
# list

# %%
a = 'Опыт работы 10 месяцев Август 2018 — по насто...'


def exprns(elem):
    try:
        counter = 0
        elem = elem.split(' ')
        if ('го' or 'ле') in elem[3]:
            counter += int(elem[2])*12
            print('1 ', counter)
            print(elem[3])
        
        if 'мес' in elem[3]:
            counter += int(elem[2])
            print('2 ', counter)
        
        if 'мес' in elem[5]:
            counter += int(elem[4])
            print('3 ', counter)
        
        return counter
    except:
        return None

exprns(a)
# Out:
# 2  10
# 10

# %%
import pandas as pd

df= pd.DataFrame( { 'a': [1, 2], 'b': [3, 4] } )

def mult(elem):
    res=int(elem)
    return res*2

df['a'] = df['a'].apply(mult)

df
# Out:
#    a  b
# 0  2  3
# 1  4  4

# %%
prefer_work_type = ['полная занятость', 'частичная занятость', 
                    'проектная работа', 'волонтёрство', 'стажировка'
                    ]

for elem in prefer_work_type:
    print(elem)
# Out:
# полная занятость
# частичная занятость
# проектная работа
# волонтёрство
# стажировка

# %%
a = 'руб.'
print(a)

# if a.isalpha() == False:
#     print('fasf')
    
# else:
#     print('fasd')

# print('end')

a = ''.join(filter(str.isalnum, a))
print(a)
# Out:
# руб.
# руб

# %%
currency = {
    'грн': 'UAH', 'USD' : 'USD', 'EUR' : 'EUR',
    'белруб' : 'BYN', 'KGS' : 'KGS', 'сум' : 'UZS',
     'AZN' : 'AZN', 'KZT' : 'KZT', 'руб' : 'RUB'
    }
currency['грн']
a = 'fd'
b = 'fg'

print(f'{a} {b}')
# Out:
# fd fg
